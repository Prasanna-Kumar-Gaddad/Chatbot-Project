# %% [markdown]
# <a href="https://colab.research.google.com/github/Shinigami-Developer/Chatbot-Project/blob/main/Pretrained_GANS/Pretrained_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from torchvision import models

# %%
dir(models)
# Out:
# ['AlexNet',
#  'DenseNet',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'Inception3',
#  'InceptionOutputs',
#  'MNASNet',
#  'MobileNetV2',
#  'MobileNetV3',
#  'ResNet',
#  'ShuffleNetV2',
#  'SqueezeNet',
#  'VGG',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_utils',
#  'alexnet',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mobilenetv2',
#  'mobilenetv3',
#  'quantization',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
# ...

# %% [markdown]
# **Using AlexNet**

# %% [markdown]
# Downloading the weights of resnet101 trained on ImageNet dataset, with 1.2 million images and 1000 categories

# %%
resnet = models.resnet101(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...

# %%
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
from torchvision import transforms
preprocess = transforms.Compose([
                                 transforms.Resize(256),
                                 transforms.CenterCrop(224),
                                 transforms.ToTensor(),
                                 transforms.Normalize(
                                     mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]
                                 )
])

# %%
from PIL import Image

img = Image.open("/content/american bull.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1003x1020 at 0x7FA56A7A4F90>

# %%
img_t = preprocess(img)
img_t
# Out:
# tensor([[[-0.8507, -0.9877, -1.1418,  ..., -0.3369, -0.3883, -0.4568],
#          [-1.0048, -1.1247, -1.2274,  ..., -0.3198, -0.3198, -0.3027],
#          [-1.1760, -1.2788, -1.3815,  ..., -0.3541, -0.3027, -0.2513],
#          ...,
#          [-1.2445, -0.3541, -1.2274,  ..., -0.4568, -0.4226, -0.4568],
#          [-0.9020, -0.7822, -1.4329,  ..., -0.4226, -0.3541, -0.3712],
#          [-0.7479, -1.2274, -1.3815,  ..., -0.4226, -0.3369, -0.3369]],
#
#         [[-0.8978, -1.0203, -1.1253,  ..., -0.3901, -0.4776, -0.5476],
#          [-1.0203, -1.1253, -1.1954,  ..., -0.4251, -0.4426, -0.4251],
#          [-1.1604, -1.2304, -1.3004,  ..., -0.4601, -0.4251, -0.3725],
#          ...,
#          [-1.1779, -0.2500, -1.1779,  ..., -0.3725, -0.3200, -0.3550],
#          [-0.8102, -0.7052, -1.4230,  ..., -0.3725, -0.2850, -0.2850],
#          [-0.6527, -1.1779, -1.3529,  ..., -0.3550, -0.2500, -0.2325]],
#
#         [[-1.7870, -1.7870, -1.8044,  ..., -0.8807, -0.9156, -0.9330],
# ...

# %%
import torch
batch_t = torch.unsqueeze(img_t, 0)

# %%
resnet.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
out = resnet(batch_t)
out
# Out:
# tensor([[ 2.3322e+00, -1.9459e+00,  1.0416e+00,  1.8259e+00, -4.8874e-01,
#          -2.8938e+00, -1.8491e+00, -1.1991e+00, -2.5236e+00, -3.2203e+00,
#          -1.2066e+00, -3.3274e-02, -3.8547e-01, -5.1417e-01, -2.0263e+00,
#          -2.1595e+00, -1.5033e-01, -6.1078e-01,  2.2866e+00, -5.4422e-01,
#          -1.6711e-01, -1.4270e+00, -2.8754e+00, -7.7494e-01, -2.1123e+00,
#           3.2626e-01,  7.8763e-01, -1.8889e-02,  1.4393e+00,  6.7535e-01,
#           1.0485e+00, -7.9857e-01,  4.9959e-01, -1.0356e+00, -1.6703e+00,
#           1.8823e+00,  1.0475e+00,  9.6082e-02, -9.0460e-02,  6.5685e-01,
#          -1.2547e+00, -1.2492e+00, -1.7830e+00, -1.6351e+00,  3.3441e-01,
#          -3.1985e-01, -1.1971e+00,  1.2897e+00, -4.8225e-01, -2.5334e+00,
#          -1.7012e+00,  2.6479e+00,  4.6142e-01,  1.5402e+00, -6.9311e-01,
#          -5.3796e-01, -1.8562e-02,  3.3396e-01, -6.2329e-02, -7.0073e-01,
#           4.6766e-01,  6.0454e-02,  8.8312e-01, -1.0032e+00, -9.2816e-01,
# ...

# %%
with open("/content/image_net_classes.txt") as f:
    labels = [line.strip() for line in f.readlines()]

# %%
_, index = torch.max(out, 1)

# %%
percentage = torch.nn.functional.softmax(out, dim=1)[0] * 100

labels[index[0]], percentage[index[0]].item()
# Out:
# ('American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier',
#  76.64240264892578)

# %%
_, indices = torch.sort(out, descending=True)

[(labels[idx], percentage[idx].item()) for idx in indices[0][:5]]
# Out:
# [('American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier',
#   76.64240264892578),
#  ('Staffordshire bullterrier, Staffordshire bull terrier', 23.01915740966797),
#  ('bull mastiff', 0.21867653727531433),
#  ('French bulldog', 0.05172574892640114),
#  ('Boston bull, Boston terrier', 0.029406128451228142)]

# %%
'76% = American pit bull terrier '
